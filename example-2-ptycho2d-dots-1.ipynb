# %% [markdown]
# ## pyNX simulation example using 2D Images
# - Objective: To reverse engineer the pynx.ptycho.simulation code to understand all of the simulation steps
# - To create a working 2D example for ANY image in the universe
# - Once simulation is understood, deep-dive into phase-retrieval and reconstruction problem. (For now, just table the 3d problem. ONLY 2D problems are considered)
#
# Here we are considering 2D ptychography using diffraction patterns simulated using images.
# ---- We can also use CXI files for 3D CDI. ----

# %% [markdown]
# ## 0. Import Libraries

# %%
import numpy as np
from numpy import pi
from scipy import misc
import sys
import timeit

from IPython import display
import matplotlib.pyplot as plt
from IPython import display
import ipywidgets as wg
import cv2
from pylab import *
# %matplotlib inline

from pynx.ptycho import simulation, shape
from pynx.ptycho import *
from pynx.utils.pattern import siemens_star
# Out:
# /opt/miniconda3/lib/python3.7/site-packages/skcuda/cublas.py:284: UserWarning: creating CUBLAS context to get version number
#   warnings.warn('creating CUBLAS context to get version number')

# %% [markdown]
# ## 1. Read any image
# - Here we are reading the same image from disk and resizing to 512x512 resolution.
# - We will use these images as amplitude and phase of the object function.

# %%
# 1.1 Amplitude image
# im = misc.face()
im = cv2.imread("6402429_preview.png",0) # Reading color image as grayscale
resized_im = cv2.resize(im[80:500, 80:500], (512, 512)) # We will always fix the image size with dimensions divisible by 8
# resized_grayscaled_im = cv2.cvtColor(resized_im, cv2.COLOR_BGR2GRAY) # Convert RGB Channels to Grayscale for easier processing


# 1.2 Phase image
ph = misc.ascent()
ph = cv2.imread("6402429_preview.png",0)
resized_ph = cv2.resize(ph[80:500, 80:500], (512, 512)) # We will always fix the image size with dimensions divisible by 8
# resized_grayscaled_ph = cv2.cvtColor(resized_ph, cv2.COLOR_BGR2GRAY) # Convert RGB Channels to Grayscale for easier processing


# Plot the resized and gray-scaled image
f, (ax1, ax2) = plt.subplots(1,2)
ax1.imshow(resized_im)
ax2.imshow(resized_ph)
plt.show()

# %% [markdown]
# ## 2. Simulate diffraction patterns for the image

# %%
##################
# Experimental settings
detector_distance = 1
wavelength = 1.5e-10
pixel_size_detector = 1e-6

# Simulation of the ptychographic data:
n = 256 # Probe pixels 256x256

# Stretch the phase to interval (-phase_stretch/2, +phase_stretch/2)
phase0 = resized_ph - resized_ph.min()
ps = 2 * np.pi
phase_stretch = ps * phase0 / phase0.max() - ps / 2.
obj = resized_im * np.exp(1j * phase_stretch)

# obj = resized_im + 1j * resized_ph # Convert the real space image to complex (Required to be fed into pyNX simulation)


### OBJECT INFORMATION
obj_info = {'type': 'phase_ampl', 'phase_stretch': pi / 2, 'alpha_win': .2}



### PROBE INFORMATION
probe_info = {'type': 'near_field', 'aperture': (80e-6, 80e-6), 'defocus': 0.5, 'shape': (n, n)}



### SCANNING METHODS (possible methods 'raster' and 'spiral')
# Here we scan 80 positions by moving the probe (moving the probe by 20 pixels after each scan and in a spiral fashion)
scan_info = {'type': 'spiral', 'scan_step_pix': 10, 'n_scans': 80}



### OUTPUT Diffraction data will depend upon the experimental settings like detector_distance(in m), wavelength of x-rays(in m), detector pixel-size(in m)
data_info = {'num_phot_max': 1e9, 'bg': 0, 'wavelength': wavelength, 'detector_distance': detector_distance,
             'detector_pixel_size': pixel_size_detector, 'noise': 'poisson', 'near_field': True}



### Initialisation of the simulation
# s = simulation.Simulation(obj_info=obj_info, probe_info=probe_info, scan_info=scan_info, data_info=data_info)
s = simulation.Simulation(obj=obj, probe_info=probe_info, scan_info=scan_info, data_info=data_info)
# Data simulation: probe.show(), obj.show(), scan.show() and s.show_illumination_sum() will visualise the integrated total coverage of the beam
s.make_data()

posy, posx = s.scan.values
ampl = s.amplitude.values  # square root of the measured diffraction pattern intensity
# Out:
# Simulating probe: near_field
# Simulating scan: spiral
# Simulating ptychographic data [80 frames].
# 80 70 60 50 40 30 20 10
#
# Parameters of the simulation:
# Data info: {'pix_size_direct_nm': 10, 'num_phot_max': 1000000000.0, 'bg': 0, 'beam_stop_transparency': 0, 'noise': 'poisson', 'wavelength': 1.5e-10, 'detector_distance': 1, 'detector_pixel_size': 1e-06, 'near_field': True}
# Scan info: {'type': 'spiral', 'scan_step_pix': 10, 'n_scans': 80, 'integer_values': True}
# Object info: {'type': 'Custom', 'border_pix': 2}
# Probe info: {'type': 'near_field', 'shape': (256, 256), 'sigma_pix': (50, 50), 'rotation': 0, 'aperture': (8e-05, 8e-05), 'defocus': 0.5}

# %%
s.obj.show()
s.probe.show()
s.scan.show()
# Out:
# amplitude_phase
# /opt/miniconda3/lib/python3.7/site-packages/pynx/utils/plot_utils.py:284: UserWarning: This figure includes Axes that are not compatible with tight_layout, so results might be incorrect.
#   plt.tight_layout()
# amplitude_phase

# %%
##################
# Evaluation:
# Size of the reconstructed object (obj)
nyo, nxo = shape.calc_obj_shape(posy, posx, ampl.shape[1:])

# Initial object
# obj_init_info = {'type':'flat','shape':(nx,ny)}
obj_init_info = {'type': 'random', 'range': (0, 1, 0, 0.5), 'shape': (nyo, nxo)}
# Initial probe
probe_init_info = {'type': 'near_field', 'aperture': (85e-6, 85e-6), 'defocus': 0.3, 'shape': (n, n)}
init = simulation.Simulation(obj_info=obj_init_info, probe_info=probe_init_info, data_info=data_info)

init.make_obj()
init.make_probe()

data = PtychoData(iobs=ampl ** 2, positions=(posy * pixel_size_detector, posx * pixel_size_detector),
                  detector_distance=detector_distance, mask=None,
                  pixel_size_detector=pixel_size_detector, wavelength=wavelength, near_field=True)

p = Ptycho(probe=init.probe.values, obj=init.obj.values, data=data, background=None)

# Initial scaling is important to avoid overflows during ML
p = ScaleObjProbe() * p
# Out:
# Simulating object: random
# Simulating probe: near_field

# %% [markdown]
# ## 3. Visualizing Diffraction patterns alongside probe position

# %%
def myplot(c):
    x = np.linspace(start=-10, stop=10, num=50)
    y = c * x**2
    fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(15, 8), dpi = 80, constrained_layout=True) # Constrained layout makes sure that the title texts don't overlap
    fig.suptitle('Scan position of probe(left) and Diffraction pattern(right)', fontsize=15)
    ax1.set_title("Spiral scan position"
                 , fontdict={'fontfamily': 'monospace'
                             , 'fontstyle': 'normal'
                             , 'fontsize': 20
                             , 'fontweight': 'medium'})
    # plt.axis('scaled')
    ax1.set_ylim([-150,150])
    ax1.set_xlim([-150,150])
    ax1.plot(s.scan.values[1][:c], s.scan.values[0][:c], '-x')
    ax1.set_xlabel('pos_hor [pixels]', fontdict={'fontfamily': 'monospace'
                             , 'fontstyle': 'normal'
                             , 'fontsize': 16
                             , 'fontweight': 'normal'})
    ax1.set_ylabel('pos_ver [pixels]', fontdict={'fontfamily': 'monospace'
                             , 'fontstyle': 'normal'
                             , 'fontsize': 16
                             , 'fontweight': 'normal'})
    ax1.grid(b=True)
    
    amplitudes=s.amplitude.values[c]
    ints=np.abs(amplitudes)**2
    im2 = ax2.imshow(np.log(ints + 0.0001),cmap='jet',vmin=0)
    ax2.set_title('Diffraction Pattern  I(q). Position: {}'.format(c+1),fontsize=18)
    
scan_number = wg.IntSlider(description = 'Scan Number:', min=0, max=s.scan.info['n_scans'])
wg.interact(myplot, c=scan_number);
# Out:
# interactive(children=(IntSlider(value=0, description='Scan Number:', max=80), Output()), _dom_classes=('widget…

# %% [markdown]
# ## 5. Phase retrieval and reconstruction

# %%
# %matplotlib inline
print("Difference Map optimization Initialized!")
p = ShowObjProbe(fig_num=1) * DM(update_object=True, update_probe=True, calc_llk=5, ) ** 1000 * p
print("Difference Map optimization completed!\nAlternating Projections optimization Initialized!")
p = ShowObjProbe(fig_num=1) * AP(update_object=True, update_probe=True, calc_llk=5) ** 1000 * p
print("Alternating Projections optimization completed!\nMaximum likelihood optimization Initialized!")
p = ShowObjProbe(fig_num=1) * ML(update_object=True, update_probe=True, calc_llk=5) ** 1000 * p
print("Maximum likelihood optimization completed!")
# Out:
# Difference Map optimization Initialized!
# DM/o/p     #3001 LLK=     3.31(p)     2.70(g)     2.70(e), nb photons=1.617592e+14, dt/cycle=0.023s
# DM/o/p     #3006 LLK=     3.30(p)     2.68(g)     2.68(e), nb photons=1.617592e+14, dt/cycle=0.019s
# DM/o/p     #3011 LLK=     3.30(p)     2.67(g)     2.67(e), nb photons=1.617592e+14, dt/cycle=0.019s
# DM/o/p     #3016 LLK=     3.29(p)     2.66(g)     2.66(e), nb photons=1.617592e+14, dt/cycle=0.018s
# DM/o/p     #3021 LLK=     3.29(p)     2.65(g)     2.65(e), nb photons=1.617592e+14, dt/cycle=0.017s
# DM/o/p     #3026 LLK=     3.29(p)     2.64(g)     2.64(e), nb photons=1.617592e+14, dt/cycle=0.016s
# DM/o/p     #3031 LLK=     3.28(p)     2.63(g)     2.63(e), nb photons=1.617592e+14, dt/cycle=0.016s
# DM/o/p     #3036 LLK=     3.27(p)     2.62(g)     2.62(e), nb photons=1.617592e+14, dt/cycle=0.016s
# DM/o/p     #3041 LLK=     3.27(p)     2.61(g)     2.61(e), nb photons=1.617592e+14, dt/cycle=0.015s
# DM/o/p     #3046 LLK=     3.26(p)     2.60(g)     2.60(e), nb photons=1.617591e+14, dt/cycle=0.015s
# DM/o/p     #3051 LLK=     3.26(p)     2.59(g)     2.59(e), nb photons=1.617591e+14, dt/cycle=0.015s
# DM/o/p     #3056 LLK=     3.26(p)     2.58(g)     2.58(e), nb photons=1.617591e+14, dt/cycle=0.015s
# DM/o/p     #3061 LLK=     3.25(p)     2.56(g)     2.57(e), nb photons=1.617591e+14, dt/cycle=0.015s
# DM/o/p     #3066 LLK=     3.24(p)     2.55(g)     2.56(e), nb photons=1.617591e+14, dt/cycle=0.015s
# DM/o/p     #3071 LLK=     3.24(p)     2.54(g)     2.55(e), nb photons=1.617591e+14, dt/cycle=0.015s
# DM/o/p     #3076 LLK=     3.23(p)     2.53(g)     2.53(e), nb photons=1.617591e+14, dt/cycle=0.015s
# DM/o/p     #3081 LLK=     3.23(p)     2.51(g)     2.52(e), nb photons=1.617591e+14, dt/cycle=0.015s
# DM/o/p     #3086 LLK=     3.22(p)     2.49(g)     2.50(e), nb photons=1.617591e+14, dt/cycle=0.015s
# DM/o/p     #3091 LLK=     3.21(p)     2.48(g)     2.49(e), nb photons=1.617591e+14, dt/cycle=0.015s
# DM/o/p     #3096 LLK=     3.21(p)     2.46(g)     2.47(e), nb photons=1.617591e+14, dt/cycle=0.015s
# DM/o/p     #3101 LLK=     3.19(p)     2.44(g)     2.45(e), nb photons=1.617591e+14, dt/cycle=0.015s
# DM/o/p     #3106 LLK=     3.19(p)     2.42(g)     2.43(e), nb photons=1.617591e+14, dt/cycle=0.015s
# DM/o/p     #3111 LLK=     3.18(p)     2.40(g)     2.41(e), nb photons=1.617591e+14, dt/cycle=0.015s
# DM/o/p     #3116 LLK=     3.17(p)     2.39(g)     2.40(e), nb photons=1.617590e+14, dt/cycle=0.015s
# DM/o/p     #3121 LLK=     3.16(p)     2.38(g)     2.39(e), nb photons=1.617591e+14, dt/cycle=0.015s
# DM/o/p     #3126 LLK=     3.16(p)     2.36(g)     2.37(e), nb photons=1.617590e+14, dt/cycle=0.015s
# DM/o/p     #3131 LLK=     3.15(p)     2.35(g)     2.36(e), nb photons=1.617590e+14, dt/cycle=0.015s
# DM/o/p     #3136 LLK=     3.14(p)     2.33(g)     2.34(e), nb photons=1.617590e+14, dt/cycle=0.015s
# DM/o/p     #3141 LLK=     3.13(p)     2.31(g)     2.32(e), nb photons=1.617590e+14, dt/cycle=0.015s
# DM/o/p     #3146 LLK=     3.12(p)     2.30(g)     2.31(e), nb photons=1.617590e+14, dt/cycle=0.015s
# DM/o/p     #3151 LLK=     3.12(p)     2.28(g)     2.29(e), nb photons=1.617590e+14, dt/cycle=0.015s
# DM/o/p     #3156 LLK=     3.11(p)     2.26(g)     2.27(e), nb photons=1.617590e+14, dt/cycle=0.015s
# DM/o/p     #3161 LLK=     3.10(p)     2.25(g)     2.26(e), nb photons=1.617590e+14, dt/cycle=0.015s
# DM/o/p     #3166 LLK=     3.09(p)     2.23(g)     2.24(e), nb photons=1.617590e+14, dt/cycle=0.015s
# DM/o/p     #3171 LLK=     3.09(p)     2.22(g)     2.23(e), nb photons=1.617590e+14, dt/cycle=0.015s
# DM/o/p     #3176 LLK=     3.08(p)     2.20(g)     2.21(e), nb photons=1.617590e+14, dt/cycle=0.015s
# DM/o/p     #3181 LLK=     3.07(p)     2.19(g)     2.20(e), nb photons=1.617590e+14, dt/cycle=0.015s
# DM/o/p     #3186 LLK=     3.06(p)     2.17(g)     2.18(e), nb photons=1.617590e+14, dt/cycle=0.015s
# DM/o/p     #3191 LLK=     3.06(p)     2.16(g)     2.17(e), nb photons=1.617589e+14, dt/cycle=0.015s
# DM/o/p     #3196 LLK=     3.05(p)     2.14(g)     2.15(e), nb photons=1.617589e+14, dt/cycle=0.015s
# DM/o/p     #3201 LLK=     3.05(p)     2.14(g)     2.15(e), nb photons=1.617590e+14, dt/cycle=0.015s
# DM/o/p     #3206 LLK=     3.04(p)     2.13(g)     2.14(e), nb photons=1.617589e+14, dt/cycle=0.015s
# DM/o/p     #3211 LLK=     3.04(p)     2.12(g)     2.14(e), nb photons=1.617590e+14, dt/cycle=0.015s
# DM/o/p     #3216 LLK=     3.04(p)     2.12(g)     2.13(e), nb photons=1.617589e+14, dt/cycle=0.015s
# DM/o/p     #3221 LLK=     3.03(p)     2.11(g)     2.13(e), nb photons=1.617590e+14, dt/cycle=0.015s
# DM/o/p     #3226 LLK=     3.06(p)     2.16(g)     2.18(e), nb photons=1.617589e+14, dt/cycle=0.015s
# DM/o/p     #3231 LLK=     3.03(p)     2.12(g)     2.13(e), nb photons=1.617589e+14, dt/cycle=0.015s
# DM/o/p     #3236 LLK=     3.06(p)     2.15(g)     2.17(e), nb photons=1.617589e+14, dt/cycle=0.015s
# DM/o/p     #3241 LLK=     3.04(p)     2.12(g)     2.14(e), nb photons=1.617589e+14, dt/cycle=0.015s
# DM/o/p     #3246 LLK=     3.04(p)     2.12(g)     2.13(e), nb photons=1.617589e+14, dt/cycle=0.015s
# DM/o/p     #3251 LLK=     3.06(p)     2.16(g)     2.18(e), nb photons=1.617589e+14, dt/cycle=0.015s
# DM/o/p     #3256 LLK=     3.05(p)     2.13(g)     2.15(e), nb photons=1.617589e+14, dt/cycle=0.015s
# DM/o/p     #3261 LLK=     3.06(p)     2.16(g)     2.18(e), nb photons=1.617589e+14, dt/cycle=0.015s
# DM/o/p     #3266 LLK=     3.06(p)     2.16(g)     2.18(e), nb photons=1.617589e+14, dt/cycle=0.015s
# DM/o/p     #3271 LLK=     3.08(p)     2.18(g)     2.20(e), nb photons=1.617589e+14, dt/cycle=0.015s
# DM/o/p     #3276 LLK=     3.12(p)     2.25(g)     2.28(e), nb photons=1.617589e+14, dt/cycle=0.015s
# DM/o/p     #3281 LLK=     3.09(p)     2.20(g)     2.22(e), nb photons=1.617589e+14, dt/cycle=0.015s
# DM/o/p     #3286 LLK=     3.11(p)     2.25(g)     2.28(e), nb photons=1.617589e+14, dt/cycle=0.015s
# DM/o/p     #3291 LLK=     3.08(p)     2.20(g)     2.22(e), nb photons=1.617589e+14, dt/cycle=0.015s
# DM/o/p     #3296 LLK=     3.13(p)     2.28(g)     2.30(e), nb photons=1.617589e+14, dt/cycle=0.015s
# DM/o/p     #3301 LLK=     3.11(p)     2.25(g)     2.28(e), nb photons=1.617589e+14, dt/cycle=0.015s
# DM/o/p     #3306 LLK=     3.14(p)     2.32(g)     2.34(e), nb photons=1.617589e+14, dt/cycle=0.015s
# DM/o/p     #3311 LLK=     3.14(p)     2.32(g)     2.34(e), nb photons=1.617588e+14, dt/cycle=0.015s
# DM/o/p     #3316 LLK=     3.16(p)     2.33(g)     2.36(e), nb photons=1.617588e+14, dt/cycle=0.015s
# DM/o/p     #3321 LLK=     3.17(p)     2.36(g)     2.39(e), nb photons=1.617589e+14, dt/cycle=0.015s
# DM/o/p     #3326 LLK=     3.18(p)     2.38(g)     2.40(e), nb photons=1.617588e+14, dt/cycle=0.015s
# DM/o/p     #3331 LLK=     3.18(p)     2.38(g)     2.41(e), nb photons=1.617588e+14, dt/cycle=0.015s
# DM/o/p     #3336 LLK=     3.20(p)     2.42(g)     2.44(e), nb photons=1.617588e+14, dt/cycle=0.015s
# DM/o/p     #3341 LLK=     3.17(p)     2.37(g)     2.39(e), nb photons=1.617588e+14, dt/cycle=0.015s
# DM/o/p     #3346 LLK=     3.20(p)     2.42(g)     2.45(e), nb photons=1.617588e+14, dt/cycle=0.015s
# DM/o/p     #3351 LLK=     3.19(p)     2.41(g)     2.43(e), nb photons=1.617588e+14, dt/cycle=0.015s
# DM/o/p     #3356 LLK=     3.18(p)     2.37(g)     2.39(e), nb photons=1.617588e+14, dt/cycle=0.015s
# DM/o/p     #3361 LLK=     3.18(p)     2.39(g)     2.41(e), nb photons=1.617588e+14, dt/cycle=0.015s
# DM/o/p     #3366 LLK=     3.16(p)     2.35(g)     2.36(e), nb photons=1.617588e+14, dt/cycle=0.015s
# DM/o/p     #3371 LLK=     3.16(p)     2.35(g)     2.37(e), nb photons=1.617588e+14, dt/cycle=0.015s
# DM/o/p     #3376 LLK=     3.17(p)     2.38(g)     2.40(e), nb photons=1.617588e+14, dt/cycle=0.015s
# DM/o/p     #3381 LLK=     3.17(p)     2.37(g)     2.39(e), nb photons=1.617588e+14, dt/cycle=0.015s
# DM/o/p     #3386 LLK=     3.16(p)     2.35(g)     2.37(e), nb photons=1.617588e+14, dt/cycle=0.015s
# DM/o/p     #3391 LLK=     3.18(p)     2.39(g)     2.41(e), nb photons=1.617588e+14, dt/cycle=0.015s
# DM/o/p     #3396 LLK=     3.14(p)     2.32(g)     2.33(e), nb photons=1.617588e+14, dt/cycle=0.015s
# DM/o/p     #3401 LLK=     3.17(p)     2.37(g)     2.39(e), nb photons=1.617588e+14, dt/cycle=0.015s
# DM/o/p     #3406 LLK=     3.15(p)     2.32(g)     2.34(e), nb photons=1.617588e+14, dt/cycle=0.015s
# DM/o/p     #3411 LLK=     3.16(p)     2.36(g)     2.38(e), nb photons=1.617588e+14, dt/cycle=0.015s
# DM/o/p     #3416 LLK=     3.15(p)     2.35(g)     2.36(e), nb photons=1.617588e+14, dt/cycle=0.015s
# DM/o/p     #3421 LLK=     3.18(p)     2.39(g)     2.41(e), nb photons=1.617588e+14, dt/cycle=0.015s
# DM/o/p     #3426 LLK=     3.16(p)     2.36(g)     2.38(e), nb photons=1.617588e+14, dt/cycle=0.015s
# DM/o/p     #3431 LLK=     3.18(p)     2.41(g)     2.43(e), nb photons=1.617588e+14, dt/cycle=0.015s
# DM/o/p     #3436 LLK=     3.18(p)     2.40(g)     2.42(e), nb photons=1.617587e+14, dt/cycle=0.015s
# DM/o/p     #3441 LLK=     3.19(p)     2.41(g)     2.43(e), nb photons=1.617587e+14, dt/cycle=0.015s
# DM/o/p     #3446 LLK=     3.19(p)     2.42(g)     2.44(e), nb photons=1.617588e+14, dt/cycle=0.015s
# DM/o/p     #3451 LLK=     3.19(p)     2.41(g)     2.43(e), nb photons=1.617588e+14, dt/cycle=0.015s
# DM/o/p     #3456 LLK=     3.22(p)     2.47(g)     2.49(e), nb photons=1.617588e+14, dt/cycle=0.015s
# DM/o/p     #3461 LLK=     3.21(p)     2.47(g)     2.49(e), nb photons=1.617588e+14, dt/cycle=0.015s
# DM/o/p     #3466 LLK=     3.24(p)     2.51(g)     2.53(e), nb photons=1.617587e+14, dt/cycle=0.015s
# DM/o/p     #3471 LLK=     3.21(p)     2.47(g)     2.49(e), nb photons=1.617587e+14, dt/cycle=0.015s
# DM/o/p     #3476 LLK=     3.24(p)     2.53(g)     2.54(e), nb photons=1.617587e+14, dt/cycle=0.015s
# DM/o/p     #3481 LLK=     3.21(p)     2.47(g)     2.49(e), nb photons=1.617587e+14, dt/cycle=0.015s
# DM/o/p     #3486 LLK=     3.26(p)     2.56(g)     2.58(e), nb photons=1.617587e+14, dt/cycle=0.015s
# DM/o/p     #3491 LLK=     3.23(p)     2.49(g)     2.51(e), nb photons=1.617587e+14, dt/cycle=0.015s
# DM/o/p     #3496 LLK=     3.26(p)     2.55(g)     2.57(e), nb photons=1.617587e+14, dt/cycle=0.015s
# DM/o/p     #3501 LLK=     3.24(p)     2.52(g)     2.54(e), nb photons=1.617587e+14, dt/cycle=0.015s
# DM/o/p     #3506 LLK=     3.26(p)     2.56(g)     2.58(e), nb photons=1.617587e+14, dt/cycle=0.015s
# DM/o/p     #3511 LLK=     3.27(p)     2.57(g)     2.60(e), nb photons=1.617587e+14, dt/cycle=0.015s
# DM/o/p     #3516 LLK=     3.25(p)     2.53(g)     2.55(e), nb photons=1.617587e+14, dt/cycle=0.015s
# DM/o/p     #3521 LLK=     3.28(p)     2.59(g)     2.61(e), nb photons=1.617587e+14, dt/cycle=0.015s
# DM/o/p     #3526 LLK=     3.25(p)     2.54(g)     2.56(e), nb photons=1.617587e+14, dt/cycle=0.015s
# DM/o/p     #3531 LLK=     3.29(p)     2.61(g)     2.63(e), nb photons=1.617587e+14, dt/cycle=0.015s
# DM/o/p     #3536 LLK=     3.23(p)     2.51(g)     2.53(e), nb photons=1.617587e+14, dt/cycle=0.015s
# DM/o/p     #3541 LLK=     3.30(p)     2.64(g)     2.66(e), nb photons=1.617587e+14, dt/cycle=0.015s
# DM/o/p     #3546 LLK=     3.25(p)     2.54(g)     2.56(e), nb photons=1.617586e+14, dt/cycle=0.015s
# DM/o/p     #3551 LLK=     3.31(p)     2.65(g)     2.67(e), nb photons=1.617587e+14, dt/cycle=0.015s
# DM/o/p     #3556 LLK=     3.29(p)     2.61(g)     2.63(e), nb photons=1.617586e+14, dt/cycle=0.015s
# DM/o/p     #3561 LLK=     3.29(p)     2.61(g)     2.63(e), nb photons=1.617587e+14, dt/cycle=0.015s
# DM/o/p     #3566 LLK=     3.29(p)     2.61(g)     2.63(e), nb photons=1.617586e+14, dt/cycle=0.015s
# DM/o/p     #3571 LLK=     3.25(p)     2.53(g)     2.55(e), nb photons=1.617587e+14, dt/cycle=0.015s
# DM/o/p     #3576 LLK=     3.31(p)     2.65(g)     2.67(e), nb photons=1.617586e+14, dt/cycle=0.015s
# DM/o/p     #3581 LLK=     3.26(p)     2.55(g)     2.56(e), nb photons=1.617586e+14, dt/cycle=0.015s
# DM/o/p     #3586 LLK=     3.31(p)     2.65(g)     2.67(e), nb photons=1.617586e+14, dt/cycle=0.015s
# DM/o/p     #3591 LLK=     3.26(p)     2.54(g)     2.56(e), nb photons=1.617586e+14, dt/cycle=0.015s
# DM/o/p     #3596 LLK=     3.29(p)     2.61(g)     2.63(e), nb photons=1.617586e+14, dt/cycle=0.015s
# DM/o/p     #3601 LLK=     3.28(p)     2.59(g)     2.61(e), nb photons=1.617586e+14, dt/cycle=0.015s
# DM/o/p     #3606 LLK=     3.28(p)     2.60(g)     2.62(e), nb photons=1.617586e+14, dt/cycle=0.015s
# DM/o/p     #3611 LLK=     3.30(p)     2.62(g)     2.64(e), nb photons=1.617586e+14, dt/cycle=0.015s
# DM/o/p     #3616 LLK=     3.27(p)     2.57(g)     2.59(e), nb photons=1.617586e+14, dt/cycle=0.015s
# DM/o/p     #3621 LLK=     3.31(p)     2.66(g)     2.68(e), nb photons=1.617586e+14, dt/cycle=0.015s
# DM/o/p     #3626 LLK=     3.26(p)     2.56(g)     2.58(e), nb photons=1.617586e+14, dt/cycle=0.015s
# DM/o/p     #3631 LLK=     3.31(p)     2.66(g)     2.68(e), nb photons=1.617586e+14, dt/cycle=0.015s
# DM/o/p     #3636 LLK=     3.28(p)     2.58(g)     2.61(e), nb photons=1.617586e+14, dt/cycle=0.015s
# DM/o/p     #3641 LLK=     3.30(p)     2.64(g)     2.66(e), nb photons=1.617586e+14, dt/cycle=0.015s
# DM/o/p     #3646 LLK=     3.31(p)     2.65(g)     2.67(e), nb photons=1.617586e+14, dt/cycle=0.015s
# DM/o/p     #3651 LLK=     3.30(p)     2.63(g)     2.65(e), nb photons=1.617586e+14, dt/cycle=0.015s
# DM/o/p     #3656 LLK=     3.33(p)     2.70(g)     2.72(e), nb photons=1.617585e+14, dt/cycle=0.015s
# DM/o/p     #3661 LLK=     3.28(p)     2.60(g)     2.62(e), nb photons=1.617586e+14, dt/cycle=0.015s
# DM/o/p     #3666 LLK=     3.34(p)     2.72(g)     2.74(e), nb photons=1.617585e+14, dt/cycle=0.015s
# DM/o/p     #3671 LLK=     3.28(p)     2.60(g)     2.63(e), nb photons=1.617586e+14, dt/cycle=0.015s
# DM/o/p     #3676 LLK=     3.33(p)     2.69(g)     2.71(e), nb photons=1.617586e+14, dt/cycle=0.015s
# DM/o/p     #3681 LLK=     3.32(p)     2.67(g)     2.69(e), nb photons=1.617585e+14, dt/cycle=0.015s
# DM/o/p     #3686 LLK=     3.33(p)     2.68(g)     2.70(e), nb photons=1.617585e+14, dt/cycle=0.015s
# DM/o/p     #3691 LLK=     3.35(p)     2.73(g)     2.75(e), nb photons=1.617585e+14, dt/cycle=0.015s
# DM/o/p     #3696 LLK=     3.32(p)     2.67(g)     2.70(e), nb photons=1.617585e+14, dt/cycle=0.015s
# DM/o/p     #3701 LLK=     3.38(p)     2.80(g)     2.82(e), nb photons=1.617585e+14, dt/cycle=0.015s
# DM/o/p     #3706 LLK=     3.34(p)     2.71(g)     2.74(e), nb photons=1.617585e+14, dt/cycle=0.015s
# DM/o/p     #3711 LLK=     3.39(p)     2.80(g)     2.83(e), nb photons=1.617585e+14, dt/cycle=0.015s
# DM/o/p     #3716 LLK=     3.36(p)     2.75(g)     2.78(e), nb photons=1.617585e+14, dt/cycle=0.015s
# DM/o/p     #3721 LLK=     3.39(p)     2.81(g)     2.83(e), nb photons=1.617585e+14, dt/cycle=0.015s
# DM/o/p     #3726 LLK=     3.39(p)     2.81(g)     2.83(e), nb photons=1.617585e+14, dt/cycle=0.015s
# DM/o/p     #3731 LLK=     3.38(p)     2.80(g)     2.82(e), nb photons=1.617585e+14, dt/cycle=0.015s
# DM/o/p     #3736 LLK=     3.43(p)     2.88(g)     2.90(e), nb photons=1.617585e+14, dt/cycle=0.015s
# DM/o/p     #3741 LLK=     3.38(p)     2.78(g)     2.81(e), nb photons=1.617585e+14, dt/cycle=0.015s
# DM/o/p     #3746 LLK=     3.44(p)     2.91(g)     2.93(e), nb photons=1.617585e+14, dt/cycle=0.015s
# DM/o/p     #3751 LLK=     3.41(p)     2.85(g)     2.88(e), nb photons=1.617585e+14, dt/cycle=0.015s
# DM/o/p     #3756 LLK=     3.46(p)     2.94(g)     2.97(e), nb photons=1.617584e+14, dt/cycle=0.015s
# DM/o/p     #3761 LLK=     3.44(p)     2.92(g)     2.94(e), nb photons=1.617584e+14, dt/cycle=0.015s
# DM/o/p     #3766 LLK=     3.43(p)     2.90(g)     2.92(e), nb photons=1.617584e+14, dt/cycle=0.015s
# DM/o/p     #3771 LLK=     3.47(p)     2.97(g)     2.99(e), nb photons=1.617584e+14, dt/cycle=0.015s
# DM/o/p     #3776 LLK=     3.44(p)     2.92(g)     2.94(e), nb photons=1.617584e+14, dt/cycle=0.015s
# DM/o/p     #3781 LLK=     3.49(p)     3.01(g)     3.03(e), nb photons=1.617584e+14, dt/cycle=0.015s
# DM/o/p     #3786 LLK=     3.46(p)     2.94(g)     2.97(e), nb photons=1.617584e+14, dt/cycle=0.015s
# DM/o/p     #3791 LLK=     3.48(p)     2.99(g)     3.01(e), nb photons=1.617584e+14, dt/cycle=0.015s
# DM/o/p     #3796 LLK=     3.47(p)     2.98(g)     3.00(e), nb photons=1.617584e+14, dt/cycle=0.015s
# DM/o/p     #3801 LLK=     3.50(p)     3.02(g)     3.04(e), nb photons=1.617584e+14, dt/cycle=0.015s
# DM/o/p     #3806 LLK=     3.50(p)     3.03(g)     3.05(e), nb photons=1.617584e+14, dt/cycle=0.015s
# DM/o/p     #3811 LLK=     3.47(p)     2.98(g)     3.00(e), nb photons=1.617584e+14, dt/cycle=0.015s
# DM/o/p     #3816 LLK=     3.51(p)     3.05(g)     3.07(e), nb photons=1.617584e+14, dt/cycle=0.015s
# DM/o/p     #3821 LLK=     3.48(p)     2.98(g)     3.01(e), nb photons=1.617584e+14, dt/cycle=0.015s
# DM/o/p     #3826 LLK=     3.53(p)     3.09(g)     3.12(e), nb photons=1.617583e+14, dt/cycle=0.015s
# DM/o/p     #3831 LLK=     3.50(p)     3.03(g)     3.06(e), nb photons=1.617583e+14, dt/cycle=0.015s
# DM/o/p     #3836 LLK=     3.53(p)     3.10(g)     3.12(e), nb photons=1.617583e+14, dt/cycle=0.015s
# DM/o/p     #3841 LLK=     3.52(p)     3.06(g)     3.09(e), nb photons=1.617583e+14, dt/cycle=0.015s
# DM/o/p     #3846 LLK=     3.52(p)     3.06(g)     3.09(e), nb photons=1.617583e+14, dt/cycle=0.015s
# DM/o/p     #3851 LLK=     3.54(p)     3.12(g)     3.14(e), nb photons=1.617583e+14, dt/cycle=0.015s
# DM/o/p     #3856 LLK=     3.51(p)     3.04(g)     3.06(e), nb photons=1.617583e+14, dt/cycle=0.015s
# DM/o/p     #3861 LLK=     3.55(p)     3.13(g)     3.15(e), nb photons=1.617583e+14, dt/cycle=0.016s
# DM/o/p     #3866 LLK=     3.52(p)     3.07(g)     3.10(e), nb photons=1.617583e+14, dt/cycle=0.015s
# DM/o/p     #3871 LLK=     3.59(p)     3.20(g)     3.23(e), nb photons=1.617583e+14, dt/cycle=0.015s
# DM/o/p     #3876 LLK=     3.57(p)     3.16(g)     3.18(e), nb photons=1.617583e+14, dt/cycle=0.015s
# DM/o/p     #3881 LLK=     3.59(p)     3.20(g)     3.23(e), nb photons=1.617583e+14, dt/cycle=0.015s
# DM/o/p     #3886 LLK=     3.59(p)     3.20(g)     3.23(e), nb photons=1.617583e+14, dt/cycle=0.015s
# DM/o/p     #3891 LLK=     3.59(p)     3.20(g)     3.23(e), nb photons=1.617583e+14, dt/cycle=0.015s
# DM/o/p     #3896 LLK=     3.62(p)     3.26(g)     3.28(e), nb photons=1.617583e+14, dt/cycle=0.015s
# DM/o/p     #3901 LLK=     3.59(p)     3.19(g)     3.22(e), nb photons=1.617583e+14, dt/cycle=0.015s
# DM/o/p     #3906 LLK=     3.61(p)     3.26(g)     3.28(e), nb photons=1.617582e+14, dt/cycle=0.015s
# DM/o/p     #3911 LLK=     3.59(p)     3.20(g)     3.23(e), nb photons=1.617582e+14, dt/cycle=0.015s
# DM/o/p     #3916 LLK=     3.64(p)     3.31(g)     3.33(e), nb photons=1.617582e+14, dt/cycle=0.015s
# DM/o/p     #3921 LLK=     3.62(p)     3.27(g)     3.29(e), nb photons=1.617582e+14, dt/cycle=0.015s
# DM/o/p     #3926 LLK=     3.66(p)     3.34(g)     3.37(e), nb photons=1.617582e+14, dt/cycle=0.016s
# DM/o/p     #3931 LLK=     3.63(p)     3.27(g)     3.30(e), nb photons=1.617582e+14, dt/cycle=0.015s
# DM/o/p     #3936 LLK=     3.63(p)     3.29(g)     3.32(e), nb photons=1.617582e+14, dt/cycle=0.015s
# DM/o/p     #3941 LLK=     3.61(p)     3.24(g)     3.27(e), nb photons=1.617582e+14, dt/cycle=0.015s
# DM/o/p     #3946 LLK=     3.62(p)     3.27(g)     3.30(e), nb photons=1.617582e+14, dt/cycle=0.015s
# DM/o/p     #3951 LLK=     3.65(p)     3.32(g)     3.35(e), nb photons=1.617581e+14, dt/cycle=0.015s
# DM/o/p     #3956 LLK=     3.64(p)     3.30(g)     3.33(e), nb photons=1.617582e+14, dt/cycle=0.015s
# DM/o/p     #3961 LLK=     3.66(p)     3.36(g)     3.39(e), nb photons=1.617582e+14, dt/cycle=0.015s
# DM/o/p     #3966 LLK=     3.62(p)     3.28(g)     3.30(e), nb photons=1.617582e+14, dt/cycle=0.015s
# DM/o/p     #3971 LLK=     3.66(p)     3.34(g)     3.37(e), nb photons=1.617581e+14, dt/cycle=0.015s
# DM/o/p     #3976 LLK=     3.61(p)     3.25(g)     3.28(e), nb photons=1.617582e+14, dt/cycle=0.015s
# DM/o/p     #3981 LLK=     3.63(p)     3.29(g)     3.31(e), nb photons=1.617581e+14, dt/cycle=0.015s
# DM/o/p     #3986 LLK=     3.62(p)     3.27(g)     3.29(e), nb photons=1.617581e+14, dt/cycle=0.015s
# DM/o/p     #3991 LLK=     3.62(p)     3.27(g)     3.29(e), nb photons=1.617581e+14, dt/cycle=0.015s
# DM/o/p     #3996 LLK=     3.65(p)     3.31(g)     3.34(e), nb photons=1.617581e+14, dt/cycle=0.015s
# DM/o/p     #4000 LLK=     3.64(p)     3.30(g)     3.33(e), nb photons=1.617581e+14, dt/cycle=0.015s
# Difference Map optimization completed!
# Alternating Projections optimization Initialized!
# AP/o/p     #4001 LLK=     3.60(p)     3.30(g)     3.32(e), nb photons=1.617593e+14, dt/cycle=0.012s
# AP/o/p     #4006 LLK=     2.99(p)     2.04(g)     2.04(e), nb photons=1.617590e+14, dt/cycle=0.010s
# AP/o/p     #4011 LLK=     2.91(p)     1.90(g)     1.90(e), nb photons=1.617594e+14, dt/cycle=0.010s
# AP/o/p     #4016 LLK=     2.90(p)     1.86(g)     1.86(e), nb photons=1.617590e+14, dt/cycle=0.010s
# AP/o/p     #4021 LLK=     2.89(p)     1.84(g)     1.84(e), nb photons=1.617593e+14, dt/cycle=0.010s
# AP/o/p     #4026 LLK=     2.89(p)     1.83(g)     1.83(e), nb photons=1.617591e+14, dt/cycle=0.010s
# AP/o/p     #4031 LLK=     2.88(p)     1.83(g)     1.83(e), nb photons=1.617593e+14, dt/cycle=0.010s
# AP/o/p     #4036 LLK=     2.89(p)     1.82(g)     1.83(e), nb photons=1.617591e+14, dt/cycle=0.010s
# AP/o/p     #4041 LLK=     2.88(p)     1.82(g)     1.82(e), nb photons=1.617593e+14, dt/cycle=0.010s
# AP/o/p     #4046 LLK=     2.88(p)     1.82(g)     1.82(e), nb photons=1.617591e+14, dt/cycle=0.010s
# AP/o/p     #4051 LLK=     2.87(p)     1.82(g)     1.82(e), nb photons=1.617593e+14, dt/cycle=0.010s
# AP/o/p     #4056 LLK=     2.88(p)     1.82(g)     1.82(e), nb photons=1.617591e+14, dt/cycle=0.010s
# AP/o/p     #4061 LLK=     2.88(p)     1.82(g)     1.82(e), nb photons=1.617593e+14, dt/cycle=0.010s
# AP/o/p     #4066 LLK=     2.88(p)     1.82(g)     1.82(e), nb photons=1.617591e+14, dt/cycle=0.010s
# AP/o/p     #4071 LLK=     2.87(p)     1.81(g)     1.81(e), nb photons=1.617593e+14, dt/cycle=0.010s
# AP/o/p     #4076 LLK=     2.88(p)     1.81(g)     1.81(e), nb photons=1.617591e+14, dt/cycle=0.010s
# AP/o/p     #4081 LLK=     2.87(p)     1.81(g)     1.81(e), nb photons=1.617593e+14, dt/cycle=0.010s
# AP/o/p     #4086 LLK=     2.88(p)     1.81(g)     1.81(e), nb photons=1.617591e+14, dt/cycle=0.010s
# AP/o/p     #4091 LLK=     2.87(p)     1.81(g)     1.81(e), nb photons=1.617592e+14, dt/cycle=0.010s
# AP/o/p     #4096 LLK=     2.88(p)     1.81(g)     1.81(e), nb photons=1.617591e+14, dt/cycle=0.010s
# AP/o/p     #4101 LLK=     2.87(p)     1.81(g)     1.81(e), nb photons=1.617593e+14, dt/cycle=0.010s
# AP/o/p     #4106 LLK=     2.88(p)     1.81(g)     1.81(e), nb photons=1.617591e+14, dt/cycle=0.010s
# AP/o/p     #4111 LLK=     2.87(p)     1.81(g)     1.81(e), nb photons=1.617593e+14, dt/cycle=0.010s
# AP/o/p     #4116 LLK=     2.87(p)     1.81(g)     1.81(e), nb photons=1.617591e+14, dt/cycle=0.010s
# AP/o/p     #4121 LLK=     2.87(p)     1.81(g)     1.81(e), nb photons=1.617592e+14, dt/cycle=0.010s
# AP/o/p     #4126 LLK=     2.87(p)     1.81(g)     1.81(e), nb photons=1.617592e+14, dt/cycle=0.010s
# AP/o/p     #4131 LLK=     2.87(p)     1.81(g)     1.81(e), nb photons=1.617592e+14, dt/cycle=0.010s
# AP/o/p     #4136 LLK=     2.87(p)     1.81(g)     1.81(e), nb photons=1.617592e+14, dt/cycle=0.010s
# AP/o/p     #4141 LLK=     2.87(p)     1.81(g)     1.81(e), nb photons=1.617592e+14, dt/cycle=0.010s
# AP/o/p     #4146 LLK=     2.87(p)     1.80(g)     1.81(e), nb photons=1.617591e+14, dt/cycle=0.010s
# AP/o/p     #4151 LLK=     2.87(p)     1.80(g)     1.80(e), nb photons=1.617593e+14, dt/cycle=0.011s
# AP/o/p     #4156 LLK=     2.87(p)     1.80(g)     1.80(e), nb photons=1.617591e+14, dt/cycle=0.010s
# AP/o/p     #4161 LLK=     2.87(p)     1.80(g)     1.80(e), nb photons=1.617593e+14, dt/cycle=0.010s
# AP/o/p     #4166 LLK=     2.87(p)     1.80(g)     1.80(e), nb photons=1.617591e+14, dt/cycle=0.010s
# AP/o/p     #4171 LLK=     2.87(p)     1.80(g)     1.80(e), nb photons=1.617593e+14, dt/cycle=0.010s
# AP/o/p     #4176 LLK=     2.87(p)     1.80(g)     1.80(e), nb photons=1.617591e+14, dt/cycle=0.010s
# AP/o/p     #4181 LLK=     2.87(p)     1.80(g)     1.80(e), nb photons=1.617593e+14, dt/cycle=0.010s
# AP/o/p     #4186 LLK=     2.87(p)     1.80(g)     1.80(e), nb photons=1.617591e+14, dt/cycle=0.010s
# AP/o/p     #4191 LLK=     2.87(p)     1.80(g)     1.80(e), nb photons=1.617593e+14, dt/cycle=0.010s
# AP/o/p     #4196 LLK=     2.87(p)     1.80(g)     1.80(e), nb photons=1.617591e+14, dt/cycle=0.010s
# AP/o/p     #4201 LLK=     2.87(p)     1.80(g)     1.80(e), nb photons=1.617592e+14, dt/cycle=0.010s
# AP/o/p     #4206 LLK=     2.87(p)     1.80(g)     1.80(e), nb photons=1.617592e+14, dt/cycle=0.010s
# AP/o/p     #4211 LLK=     2.87(p)     1.80(g)     1.80(e), nb photons=1.617592e+14, dt/cycle=0.010s
# AP/o/p     #4216 LLK=     2.87(p)     1.80(g)     1.80(e), nb photons=1.617592e+14, dt/cycle=0.010s
# AP/o/p     #4221 LLK=     2.87(p)     1.80(g)     1.80(e), nb photons=1.617592e+14, dt/cycle=0.010s
# AP/o/p     #4226 LLK=     2.87(p)     1.80(g)     1.80(e), nb photons=1.617592e+14, dt/cycle=0.010s
# AP/o/p     #4231 LLK=     2.87(p)     1.80(g)     1.80(e), nb photons=1.617592e+14, dt/cycle=0.010s
# AP/o/p     #4236 LLK=     2.86(p)     1.80(g)     1.80(e), nb photons=1.617592e+14, dt/cycle=0.010s
# AP/o/p     #4241 LLK=     2.87(p)     1.80(g)     1.80(e), nb photons=1.617592e+14, dt/cycle=0.010s
# AP/o/p     #4246 LLK=     2.87(p)     1.80(g)     1.80(e), nb photons=1.617592e+14, dt/cycle=0.010s
# AP/o/p     #4251 LLK=     2.86(p)     1.80(g)     1.80(e), nb photons=1.617592e+14, dt/cycle=0.010s
# AP/o/p     #4256 LLK=     2.86(p)     1.80(g)     1.80(e), nb photons=1.617592e+14, dt/cycle=0.010s
# AP/o/p     #4261 LLK=     2.87(p)     1.79(g)     1.80(e), nb photons=1.617593e+14, dt/cycle=0.010s
# AP/o/p     #4266 LLK=     2.86(p)     1.79(g)     1.80(e), nb photons=1.617591e+14, dt/cycle=0.010s
# AP/o/p     #4271 LLK=     2.86(p)     1.79(g)     1.79(e), nb photons=1.617592e+14, dt/cycle=0.010s
# AP/o/p     #4276 LLK=     2.87(p)     1.79(g)     1.79(e), nb photons=1.617592e+14, dt/cycle=0.010s
# AP/o/p     #4281 LLK=     2.86(p)     1.79(g)     1.79(e), nb photons=1.617592e+14, dt/cycle=0.010s
# AP/o/p     #4286 LLK=     2.86(p)     1.79(g)     1.79(e), nb photons=1.617592e+14, dt/cycle=0.010s
# AP/o/p     #4291 LLK=     2.86(p)     1.79(g)     1.79(e), nb photons=1.617592e+14, dt/cycle=0.010s
# AP/o/p     #4296 LLK=     2.86(p)     1.79(g)     1.79(e), nb photons=1.617592e+14, dt/cycle=0.010s
# AP/o/p     #4301 LLK=     2.86(p)     1.79(g)     1.79(e), nb photons=1.617592e+14, dt/cycle=0.010s
# AP/o/p     #4306 LLK=     2.87(p)     1.79(g)     1.79(e), nb photons=1.617591e+14, dt/cycle=0.010s
# AP/o/p     #4311 LLK=     2.86(p)     1.79(g)     1.79(e), nb photons=1.617593e+14, dt/cycle=0.010s
# AP/o/p     #4316 LLK=     2.87(p)     1.79(g)     1.79(e), nb photons=1.617591e+14, dt/cycle=0.010s
# AP/o/p     #4321 LLK=     2.86(p)     1.79(g)     1.79(e), nb photons=1.617593e+14, dt/cycle=0.010s
# AP/o/p     #4326 LLK=     2.87(p)     1.79(g)     1.79(e), nb photons=1.617591e+14, dt/cycle=0.010s
# AP/o/p     #4331 LLK=     2.86(p)     1.79(g)     1.79(e), nb photons=1.617593e+14, dt/cycle=0.010s
# AP/o/p     #4336 LLK=     2.87(p)     1.79(g)     1.79(e), nb photons=1.617591e+14, dt/cycle=0.010s
# AP/o/p     #4341 LLK=     2.86(p)     1.79(g)     1.79(e), nb photons=1.617593e+14, dt/cycle=0.010s
# AP/o/p     #4346 LLK=     2.87(p)     1.79(g)     1.79(e), nb photons=1.617591e+14, dt/cycle=0.010s
# AP/o/p     #4351 LLK=     2.86(p)     1.79(g)     1.79(e), nb photons=1.617593e+14, dt/cycle=0.010s
# AP/o/p     #4356 LLK=     2.87(p)     1.79(g)     1.79(e), nb photons=1.617591e+14, dt/cycle=0.010s
# AP/o/p     #4361 LLK=     2.86(p)     1.79(g)     1.79(e), nb photons=1.617593e+14, dt/cycle=0.010s
# AP/o/p     #4366 LLK=     2.86(p)     1.79(g)     1.79(e), nb photons=1.617591e+14, dt/cycle=0.010s
# AP/o/p     #4371 LLK=     2.86(p)     1.79(g)     1.79(e), nb photons=1.617592e+14, dt/cycle=0.010s
# AP/o/p     #4376 LLK=     2.86(p)     1.79(g)     1.79(e), nb photons=1.617592e+14, dt/cycle=0.010s
# AP/o/p     #4381 LLK=     2.86(p)     1.79(g)     1.79(e), nb photons=1.617592e+14, dt/cycle=0.011s
# AP/o/p     #4386 LLK=     2.86(p)     1.79(g)     1.79(e), nb photons=1.617592e+14, dt/cycle=0.010s
# AP/o/p     #4391 LLK=     2.86(p)     1.79(g)     1.79(e), nb photons=1.617592e+14, dt/cycle=0.010s
# AP/o/p     #4396 LLK=     2.86(p)     1.79(g)     1.79(e), nb photons=1.617592e+14, dt/cycle=0.010s
# AP/o/p     #4401 LLK=     2.86(p)     1.79(g)     1.79(e), nb photons=1.617592e+14, dt/cycle=0.010s
# AP/o/p     #4406 LLK=     2.86(p)     1.78(g)     1.79(e), nb photons=1.617592e+14, dt/cycle=0.010s
# AP/o/p     #4411 LLK=     2.86(p)     1.78(g)     1.79(e), nb photons=1.617592e+14, dt/cycle=0.010s
# AP/o/p     #4416 LLK=     2.86(p)     1.78(g)     1.78(e), nb photons=1.617592e+14, dt/cycle=0.010s
# AP/o/p     #4421 LLK=     2.86(p)     1.78(g)     1.78(e), nb photons=1.617592e+14, dt/cycle=0.010s
# AP/o/p     #4426 LLK=     2.86(p)     1.78(g)     1.78(e), nb photons=1.617592e+14, dt/cycle=0.010s
# AP/o/p     #4431 LLK=     2.86(p)     1.78(g)     1.78(e), nb photons=1.617592e+14, dt/cycle=0.010s
# AP/o/p     #4436 LLK=     2.86(p)     1.78(g)     1.78(e), nb photons=1.617592e+14, dt/cycle=0.010s
# AP/o/p     #4441 LLK=     2.86(p)     1.78(g)     1.78(e), nb photons=1.617592e+14, dt/cycle=0.010s
# AP/o/p     #4446 LLK=     2.86(p)     1.78(g)     1.78(e), nb photons=1.617592e+14, dt/cycle=0.010s
# AP/o/p     #4451 LLK=     2.86(p)     1.78(g)     1.78(e), nb photons=1.617592e+14, dt/cycle=0.010s
# AP/o/p     #4456 LLK=     2.86(p)     1.78(g)     1.78(e), nb photons=1.617592e+14, dt/cycle=0.010s
# AP/o/p     #4461 LLK=     2.86(p)     1.78(g)     1.78(e), nb photons=1.617592e+14, dt/cycle=0.010s
# AP/o/p     #4466 LLK=     2.86(p)     1.78(g)     1.78(e), nb photons=1.617592e+14, dt/cycle=0.010s
# AP/o/p     #4471 LLK=     2.86(p)     1.78(g)     1.78(e), nb photons=1.617592e+14, dt/cycle=0.010s
# AP/o/p     #4476 LLK=     2.86(p)     1.78(g)     1.78(e), nb photons=1.617592e+14, dt/cycle=0.010s
# AP/o/p     #4481 LLK=     2.86(p)     1.78(g)     1.78(e), nb photons=1.617592e+14, dt/cycle=0.010s
# AP/o/p     #4486 LLK=     2.86(p)     1.78(g)     1.78(e), nb photons=1.617592e+14, dt/cycle=0.010s
# AP/o/p     #4491 LLK=     2.86(p)     1.78(g)     1.78(e), nb photons=1.617592e+14, dt/cycle=0.010s
# AP/o/p     #4496 LLK=     2.86(p)     1.78(g)     1.78(e), nb photons=1.617592e+14, dt/cycle=0.010s
# AP/o/p     #4501 LLK=     2.85(p)     1.78(g)     1.78(e), nb photons=1.617593e+14, dt/cycle=0.010s
# AP/o/p     #4506 LLK=     2.86(p)     1.78(g)     1.78(e), nb photons=1.617591e+14, dt/cycle=0.010s
# AP/o/p     #4511 LLK=     2.86(p)     1.78(g)     1.78(e), nb photons=1.617593e+14, dt/cycle=0.010s
# AP/o/p     #4516 LLK=     2.86(p)     1.78(g)     1.78(e), nb photons=1.617591e+14, dt/cycle=0.010s
# AP/o/p     #4521 LLK=     2.86(p)     1.78(g)     1.78(e), nb photons=1.617593e+14, dt/cycle=0.010s
# AP/o/p     #4526 LLK=     2.86(p)     1.78(g)     1.78(e), nb photons=1.617591e+14, dt/cycle=0.010s
# AP/o/p     #4531 LLK=     2.85(p)     1.78(g)     1.78(e), nb photons=1.617592e+14, dt/cycle=0.010s
# AP/o/p     #4536 LLK=     2.86(p)     1.78(g)     1.78(e), nb photons=1.617591e+14, dt/cycle=0.010s
# AP/o/p     #4541 LLK=     2.86(p)     1.78(g)     1.78(e), nb photons=1.617592e+14, dt/cycle=0.010s
# AP/o/p     #4546 LLK=     2.86(p)     1.78(g)     1.78(e), nb photons=1.617592e+14, dt/cycle=0.010s
# AP/o/p     #4551 LLK=     2.86(p)     1.78(g)     1.78(e), nb photons=1.617592e+14, dt/cycle=0.010s
# AP/o/p     #4556 LLK=     2.86(p)     1.78(g)     1.78(e), nb photons=1.617592e+14, dt/cycle=0.010s
# AP/o/p     #4561 LLK=     2.85(p)     1.78(g)     1.78(e), nb photons=1.617592e+14, dt/cycle=0.010s
# AP/o/p     #4566 LLK=     2.86(p)     1.78(g)     1.78(e), nb photons=1.617592e+14, dt/cycle=0.010s
# AP/o/p     #4571 LLK=     2.85(p)     1.77(g)     1.78(e), nb photons=1.617592e+14, dt/cycle=0.010s
# AP/o/p     #4576 LLK=     2.86(p)     1.77(g)     1.77(e), nb photons=1.617592e+14, dt/cycle=0.010s
# AP/o/p     #4581 LLK=     2.86(p)     1.77(g)     1.77(e), nb photons=1.617592e+14, dt/cycle=0.010s
# AP/o/p     #4586 LLK=     2.86(p)     1.77(g)     1.77(e), nb photons=1.617592e+14, dt/cycle=0.010s
# AP/o/p     #4591 LLK=     2.85(p)     1.77(g)     1.77(e), nb photons=1.617592e+14, dt/cycle=0.010s
# AP/o/p     #4596 LLK=     2.86(p)     1.77(g)     1.77(e), nb photons=1.617592e+14, dt/cycle=0.010s
# AP/o/p     #4601 LLK=     2.86(p)     1.77(g)     1.77(e), nb photons=1.617592e+14, dt/cycle=0.010s
# AP/o/p     #4606 LLK=     2.86(p)     1.77(g)     1.77(e), nb photons=1.617592e+14, dt/cycle=0.010s
# AP/o/p     #4611 LLK=     2.85(p)     1.77(g)     1.77(e), nb photons=1.617592e+14, dt/cycle=0.010s
# AP/o/p     #4616 LLK=     2.86(p)     1.77(g)     1.77(e), nb photons=1.617592e+14, dt/cycle=0.010s
# AP/o/p     #4621 LLK=     2.85(p)     1.77(g)     1.77(e), nb photons=1.617592e+14, dt/cycle=0.010s
# AP/o/p     #4626 LLK=     2.85(p)     1.77(g)     1.77(e), nb photons=1.617592e+14, dt/cycle=0.010s
# AP/o/p     #4631 LLK=     2.85(p)     1.77(g)     1.77(e), nb photons=1.617592e+14, dt/cycle=0.010s
# AP/o/p     #4636 LLK=     2.86(p)     1.77(g)     1.77(e), nb photons=1.617592e+14, dt/cycle=0.010s
# AP/o/p     #4641 LLK=     2.85(p)     1.77(g)     1.77(e), nb photons=1.617592e+14, dt/cycle=0.010s
# AP/o/p     #4646 LLK=     2.86(p)     1.77(g)     1.77(e), nb photons=1.617592e+14, dt/cycle=0.010s
# AP/o/p     #4651 LLK=     2.85(p)     1.77(g)     1.77(e), nb photons=1.617593e+14, dt/cycle=0.010s
# AP/o/p     #4656 LLK=     2.86(p)     1.77(g)     1.77(e), nb photons=1.617591e+14, dt/cycle=0.010s
# AP/o/p     #4661 LLK=     2.85(p)     1.77(g)     1.77(e), nb photons=1.617593e+14, dt/cycle=0.010s
# AP/o/p     #4666 LLK=     2.86(p)     1.77(g)     1.77(e), nb photons=1.617591e+14, dt/cycle=0.010s
# AP/o/p     #4671 LLK=     2.85(p)     1.77(g)     1.77(e), nb photons=1.617593e+14, dt/cycle=0.010s
# AP/o/p     #4676 LLK=     2.85(p)     1.77(g)     1.77(e), nb photons=1.617591e+14, dt/cycle=0.010s
# AP/o/p     #4681 LLK=     2.85(p)     1.77(g)     1.77(e), nb photons=1.617593e+14, dt/cycle=0.010s
# AP/o/p     #4686 LLK=     2.86(p)     1.77(g)     1.77(e), nb photons=1.617591e+14, dt/cycle=0.010s
# AP/o/p     #4691 LLK=     2.85(p)     1.77(g)     1.77(e), nb photons=1.617593e+14, dt/cycle=0.010s
# AP/o/p     #4696 LLK=     2.85(p)     1.77(g)     1.77(e), nb photons=1.617592e+14, dt/cycle=0.010s
# AP/o/p     #4701 LLK=     2.85(p)     1.77(g)     1.77(e), nb photons=1.617592e+14, dt/cycle=0.010s
# AP/o/p     #4706 LLK=     2.85(p)     1.77(g)     1.77(e), nb photons=1.617592e+14, dt/cycle=0.010s
# AP/o/p     #4711 LLK=     2.85(p)     1.77(g)     1.77(e), nb photons=1.617592e+14, dt/cycle=0.010s
# AP/o/p     #4716 LLK=     2.85(p)     1.77(g)     1.77(e), nb photons=1.617592e+14, dt/cycle=0.010s
# AP/o/p     #4721 LLK=     2.85(p)     1.77(g)     1.77(e), nb photons=1.617592e+14, dt/cycle=0.010s
# AP/o/p     #4726 LLK=     2.85(p)     1.77(g)     1.77(e), nb photons=1.617592e+14, dt/cycle=0.010s
# AP/o/p     #4731 LLK=     2.85(p)     1.77(g)     1.77(e), nb photons=1.617592e+14, dt/cycle=0.010s
# AP/o/p     #4736 LLK=     2.85(p)     1.77(g)     1.77(e), nb photons=1.617592e+14, dt/cycle=0.010s
# AP/o/p     #4741 LLK=     2.85(p)     1.77(g)     1.77(e), nb photons=1.617592e+14, dt/cycle=0.010s
# AP/o/p     #4746 LLK=     2.86(p)     1.76(g)     1.77(e), nb photons=1.617592e+14, dt/cycle=0.010s
# AP/o/p     #4751 LLK=     2.85(p)     1.76(g)     1.77(e), nb photons=1.617592e+14, dt/cycle=0.010s
# AP/o/p     #4756 LLK=     2.85(p)     1.76(g)     1.76(e), nb photons=1.617592e+14, dt/cycle=0.010s
# AP/o/p     #4761 LLK=     2.85(p)     1.76(g)     1.76(e), nb photons=1.617592e+14, dt/cycle=0.010s
# AP/o/p     #4766 LLK=     2.85(p)     1.76(g)     1.76(e), nb photons=1.617592e+14, dt/cycle=0.010s
# AP/o/p     #4771 LLK=     2.85(p)     1.76(g)     1.76(e), nb photons=1.617592e+14, dt/cycle=0.010s
# AP/o/p     #4776 LLK=     2.85(p)     1.76(g)     1.76(e), nb photons=1.617592e+14, dt/cycle=0.010s
# AP/o/p     #4781 LLK=     2.85(p)     1.76(g)     1.76(e), nb photons=1.617592e+14, dt/cycle=0.010s
# AP/o/p     #4786 LLK=     2.85(p)     1.76(g)     1.76(e), nb photons=1.617592e+14, dt/cycle=0.010s
# AP/o/p     #4791 LLK=     2.85(p)     1.76(g)     1.76(e), nb photons=1.617592e+14, dt/cycle=0.010s
# AP/o/p     #4796 LLK=     2.85(p)     1.76(g)     1.76(e), nb photons=1.617592e+14, dt/cycle=0.010s
# AP/o/p     #4801 LLK=     2.85(p)     1.76(g)     1.76(e), nb photons=1.617592e+14, dt/cycle=0.010s
# AP/o/p     #4806 LLK=     2.85(p)     1.76(g)     1.76(e), nb photons=1.617592e+14, dt/cycle=0.010s
# AP/o/p     #4811 LLK=     2.85(p)     1.76(g)     1.76(e), nb photons=1.617592e+14, dt/cycle=0.010s
# AP/o/p     #4816 LLK=     2.85(p)     1.76(g)     1.76(e), nb photons=1.617592e+14, dt/cycle=0.010s
# AP/o/p     #4821 LLK=     2.84(p)     1.76(g)     1.76(e), nb photons=1.617593e+14, dt/cycle=0.010s
# AP/o/p     #4826 LLK=     2.85(p)     1.76(g)     1.76(e), nb photons=1.617591e+14, dt/cycle=0.010s
# AP/o/p     #4831 LLK=     2.84(p)     1.76(g)     1.76(e), nb photons=1.617593e+14, dt/cycle=0.010s
# AP/o/p     #4836 LLK=     2.85(p)     1.76(g)     1.76(e), nb photons=1.617591e+14, dt/cycle=0.010s
# AP/o/p     #4841 LLK=     2.85(p)     1.76(g)     1.76(e), nb photons=1.617593e+14, dt/cycle=0.010s
# AP/o/p     #4846 LLK=     2.85(p)     1.76(g)     1.76(e), nb photons=1.617591e+14, dt/cycle=0.010s
# AP/o/p     #4851 LLK=     2.84(p)     1.76(g)     1.76(e), nb photons=1.617593e+14, dt/cycle=0.010s
# AP/o/p     #4856 LLK=     2.85(p)     1.76(g)     1.76(e), nb photons=1.617591e+14, dt/cycle=0.010s
# AP/o/p     #4861 LLK=     2.85(p)     1.76(g)     1.76(e), nb photons=1.617593e+14, dt/cycle=0.010s
# AP/o/p     #4866 LLK=     2.85(p)     1.76(g)     1.76(e), nb photons=1.617591e+14, dt/cycle=0.010s
# AP/o/p     #4871 LLK=     2.84(p)     1.76(g)     1.76(e), nb photons=1.617593e+14, dt/cycle=0.010s
# AP/o/p     #4876 LLK=     2.85(p)     1.76(g)     1.76(e), nb photons=1.617591e+14, dt/cycle=0.010s
# AP/o/p     #4881 LLK=     2.84(p)     1.76(g)     1.76(e), nb photons=1.617593e+14, dt/cycle=0.010s
# AP/o/p     #4886 LLK=     2.85(p)     1.76(g)     1.76(e), nb photons=1.617591e+14, dt/cycle=0.010s
# AP/o/p     #4891 LLK=     2.84(p)     1.76(g)     1.76(e), nb photons=1.617593e+14, dt/cycle=0.010s
# AP/o/p     #4896 LLK=     2.85(p)     1.76(g)     1.76(e), nb photons=1.617591e+14, dt/cycle=0.010s
# AP/o/p     #4901 LLK=     2.85(p)     1.76(g)     1.76(e), nb photons=1.617593e+14, dt/cycle=0.010s
# AP/o/p     #4906 LLK=     2.85(p)     1.76(g)     1.76(e), nb photons=1.617591e+14, dt/cycle=0.010s
# AP/o/p     #4911 LLK=     2.84(p)     1.76(g)     1.76(e), nb photons=1.617593e+14, dt/cycle=0.010s
# AP/o/p     #4916 LLK=     2.85(p)     1.76(g)     1.76(e), nb photons=1.617591e+14, dt/cycle=0.010s
# AP/o/p     #4921 LLK=     2.84(p)     1.76(g)     1.76(e), nb photons=1.617593e+14, dt/cycle=0.010s
# AP/o/p     #4926 LLK=     2.85(p)     1.76(g)     1.76(e), nb photons=1.617591e+14, dt/cycle=0.010s
# AP/o/p     #4931 LLK=     2.84(p)     1.76(g)     1.76(e), nb photons=1.617592e+14, dt/cycle=0.010s
# AP/o/p     #4936 LLK=     2.85(p)     1.75(g)     1.76(e), nb photons=1.617592e+14, dt/cycle=0.010s
# AP/o/p     #4941 LLK=     2.84(p)     1.75(g)     1.75(e), nb photons=1.617592e+14, dt/cycle=0.010s
# AP/o/p     #4946 LLK=     2.85(p)     1.75(g)     1.75(e), nb photons=1.617591e+14, dt/cycle=0.010s
# AP/o/p     #4951 LLK=     2.84(p)     1.75(g)     1.75(e), nb photons=1.617593e+14, dt/cycle=0.010s
# AP/o/p     #4956 LLK=     2.85(p)     1.75(g)     1.75(e), nb photons=1.617591e+14, dt/cycle=0.010s
# AP/o/p     #4961 LLK=     2.84(p)     1.75(g)     1.75(e), nb photons=1.617593e+14, dt/cycle=0.010s
# AP/o/p     #4966 LLK=     2.85(p)     1.75(g)     1.75(e), nb photons=1.617592e+14, dt/cycle=0.010s
# AP/o/p     #4971 LLK=     2.84(p)     1.75(g)     1.75(e), nb photons=1.617592e+14, dt/cycle=0.010s
# AP/o/p     #4976 LLK=     2.85(p)     1.75(g)     1.75(e), nb photons=1.617592e+14, dt/cycle=0.010s
# AP/o/p     #4981 LLK=     2.84(p)     1.75(g)     1.75(e), nb photons=1.617592e+14, dt/cycle=0.010s
# AP/o/p     #4986 LLK=     2.85(p)     1.75(g)     1.75(e), nb photons=1.617592e+14, dt/cycle=0.010s
# AP/o/p     #4991 LLK=     2.84(p)     1.75(g)     1.75(e), nb photons=1.617592e+14, dt/cycle=0.010s
# AP/o/p     #4996 LLK=     2.84(p)     1.75(g)     1.75(e), nb photons=1.617592e+14, dt/cycle=0.010s
# AP/o/p     #5000 LLK=     2.84(p)     1.75(g)     1.75(e), nb photons=1.617592e+14, dt/cycle=0.010s
# Alternating Projections optimization completed!
# Maximum likelihood optimization Initialized!
# ML/o/p     #5002 LLK=     2.85(p)     1.75(g)     1.75(e), nb photons=1.617592e+14, dt/cycle=0.029s
# ML/o/p     #5007 LLK=     2.84(p)     1.75(g)     1.75(e), nb photons=1.617592e+14, dt/cycle=0.028s
# ML/o/p     #5012 LLK=     2.84(p)     1.75(g)     1.75(e), nb photons=1.617592e+14, dt/cycle=0.027s
# ML/o/p     #5017 LLK=     2.84(p)     1.75(g)     1.75(e), nb photons=1.617593e+14, dt/cycle=0.028s
# ML/o/p     #5022 LLK=     2.84(p)     1.75(g)     1.75(e), nb photons=1.617592e+14, dt/cycle=0.027s
# ML/o/p     #5027 LLK=     2.84(p)     1.75(g)     1.75(e), nb photons=1.617592e+14, dt/cycle=0.028s
# ML/o/p     #5032 LLK=     2.84(p)     1.75(g)     1.75(e), nb photons=1.617592e+14, dt/cycle=0.027s
# ML/o/p     #5037 LLK=     2.84(p)     1.74(g)     1.74(e), nb photons=1.617592e+14, dt/cycle=0.027s
# ML/o/p     #5042 LLK=     2.83(p)     1.74(g)     1.74(e), nb photons=1.617593e+14, dt/cycle=0.028s
# ML/o/p     #5047 LLK=     2.84(p)     1.74(g)     1.74(e), nb photons=1.617592e+14, dt/cycle=0.027s
# ML/o/p     #5052 LLK=     2.83(p)     1.73(g)     1.73(e), nb photons=1.617592e+14, dt/cycle=0.027s
# ML/o/p     #5057 LLK=     2.83(p)     1.73(g)     1.73(e), nb photons=1.617592e+14, dt/cycle=0.027s
# ML/o/p     #5062 LLK=     2.83(p)     1.72(g)     1.72(e), nb photons=1.617592e+14, dt/cycle=0.028s
# ML/o/p     #5067 LLK=     2.82(p)     1.72(g)     1.72(e), nb photons=1.617593e+14, dt/cycle=0.027s
# ML/o/p     #5072 LLK=     2.82(p)     1.71(g)     1.71(e), nb photons=1.617593e+14, dt/cycle=0.027s
# ML/o/p     #5077 LLK=     2.82(p)     1.70(g)     1.70(e), nb photons=1.617592e+14, dt/cycle=0.028s
# ML/o/p     #5082 LLK=     2.81(p)     1.69(g)     1.69(e), nb photons=1.617592e+14, dt/cycle=0.028s
# ML/o/p     #5087 LLK=     2.81(p)     1.68(g)     1.68(e), nb photons=1.617593e+14, dt/cycle=0.027s
# ML/o/p     #5092 LLK=     2.81(p)     1.67(g)     1.67(e), nb photons=1.617593e+14, dt/cycle=0.027s
# ML/o/p     #5097 LLK=     2.80(p)     1.66(g)     1.66(e), nb photons=1.617592e+14, dt/cycle=0.027s
# ML/o/p     #5102 LLK=     2.80(p)     1.65(g)     1.65(e), nb photons=1.617591e+14, dt/cycle=0.028s
# ML/o/p     #5107 LLK=     2.79(p)     1.65(g)     1.64(e), nb photons=1.617592e+14, dt/cycle=0.028s
# ML/o/p     #5112 LLK=     2.79(p)     1.64(g)     1.64(e), nb photons=1.617593e+14, dt/cycle=0.027s
# ML/o/p     #5117 LLK=     2.78(p)     1.63(g)     1.63(e), nb photons=1.617593e+14, dt/cycle=0.028s
# ML/o/p     #5122 LLK=     2.78(p)     1.62(g)     1.62(e), nb photons=1.617592e+14, dt/cycle=0.028s
# ML/o/p     #5127 LLK=     2.78(p)     1.61(g)     1.61(e), nb photons=1.617592e+14, dt/cycle=0.028s
# ML/o/p     #5132 LLK=     2.77(p)     1.61(g)     1.61(e), nb photons=1.617592e+14, dt/cycle=0.027s
# ML/o/p     #5137 LLK=     2.77(p)     1.60(g)     1.60(e), nb photons=1.617593e+14, dt/cycle=0.028s
# ML/o/p     #5142 LLK=     2.77(p)     1.60(g)     1.60(e), nb photons=1.617592e+14, dt/cycle=0.027s
# ML/o/p     #5147 LLK=     2.77(p)     1.60(g)     1.60(e), nb photons=1.617592e+14, dt/cycle=0.028s
# ML/o/p     #5152 LLK=     2.76(p)     1.59(g)     1.59(e), nb photons=1.617592e+14, dt/cycle=0.028s
# ML/o/p     #5157 LLK=     2.76(p)     1.59(g)     1.59(e), nb photons=1.617593e+14, dt/cycle=0.028s
# ML/o/p     #5162 LLK=     2.76(p)     1.58(g)     1.58(e), nb photons=1.617593e+14, dt/cycle=0.027s
# ML/o/p     #5167 LLK=     2.76(p)     1.58(g)     1.58(e), nb photons=1.617592e+14, dt/cycle=0.028s
# ML/o/p     #5172 LLK=     2.76(p)     1.58(g)     1.58(e), nb photons=1.617592e+14, dt/cycle=0.027s
# ML/o/p     #5177 LLK=     2.75(p)     1.58(g)     1.58(e), nb photons=1.617592e+14, dt/cycle=0.028s
# ML/o/p     #5182 LLK=     2.75(p)     1.58(g)     1.58(e), nb photons=1.617593e+14, dt/cycle=0.027s
# ML/o/p     #5187 LLK=     2.75(p)     1.57(g)     1.57(e), nb photons=1.617593e+14, dt/cycle=0.028s
# ML/o/p     #5192 LLK=     2.75(p)     1.57(g)     1.57(e), nb photons=1.617592e+14, dt/cycle=0.028s
# ML/o/p     #5197 LLK=     2.75(p)     1.57(g)     1.57(e), nb photons=1.617592e+14, dt/cycle=0.028s
# ML/o/p     #5202 LLK=     2.75(p)     1.57(g)     1.57(e), nb photons=1.617592e+14, dt/cycle=0.027s
# ML/o/p     #5207 LLK=     2.75(p)     1.57(g)     1.57(e), nb photons=1.617593e+14, dt/cycle=0.028s
# ML/o/p     #5212 LLK=     2.75(p)     1.57(g)     1.57(e), nb photons=1.617592e+14, dt/cycle=0.028s
# ML/o/p     #5217 LLK=     2.75(p)     1.56(g)     1.56(e), nb photons=1.617592e+14, dt/cycle=0.027s
# ML/o/p     #5222 LLK=     2.75(p)     1.56(g)     1.56(e), nb photons=1.617592e+14, dt/cycle=0.027s
# ML/o/p     #5227 LLK=     2.75(p)     1.56(g)     1.56(e), nb photons=1.617593e+14, dt/cycle=0.027s
# ML/o/p     #5232 LLK=     2.75(p)     1.56(g)     1.56(e), nb photons=1.617593e+14, dt/cycle=0.028s
# ML/o/p     #5237 LLK=     2.75(p)     1.56(g)     1.56(e), nb photons=1.617592e+14, dt/cycle=0.027s
# ML/o/p     #5242 LLK=     2.75(p)     1.56(g)     1.56(e), nb photons=1.617592e+14, dt/cycle=0.027s
# ML/o/p     #5247 LLK=     2.75(p)     1.55(g)     1.55(e), nb photons=1.617592e+14, dt/cycle=0.027s
# ML/o/p     #5252 LLK=     2.74(p)     1.55(g)     1.55(e), nb photons=1.617593e+14, dt/cycle=0.027s
# ML/o/p     #5257 LLK=     2.74(p)     1.55(g)     1.55(e), nb photons=1.617592e+14, dt/cycle=0.027s
# ML/o/p     #5262 LLK=     2.74(p)     1.55(g)     1.55(e), nb photons=1.617592e+14, dt/cycle=0.027s
# ML/o/p     #5267 LLK=     2.74(p)     1.54(g)     1.54(e), nb photons=1.617593e+14, dt/cycle=0.027s
# ML/o/p     #5272 LLK=     2.74(p)     1.54(g)     1.54(e), nb photons=1.617592e+14, dt/cycle=0.027s
# ML/o/p     #5277 LLK=     2.73(p)     1.54(g)     1.54(e), nb photons=1.617592e+14, dt/cycle=0.027s
# ML/o/p     #5282 LLK=     2.73(p)     1.54(g)     1.54(e), nb photons=1.617593e+14, dt/cycle=0.027s
# ML/o/p     #5287 LLK=     2.73(p)     1.53(g)     1.53(e), nb photons=1.617593e+14, dt/cycle=0.027s
# ML/o/p     #5292 LLK=     2.74(p)     1.53(g)     1.53(e), nb photons=1.617592e+14, dt/cycle=0.028s
# ML/o/p     #5297 LLK=     2.73(p)     1.53(g)     1.53(e), nb photons=1.617592e+14, dt/cycle=0.027s
# ML/o/p     #5302 LLK=     2.73(p)     1.53(g)     1.53(e), nb photons=1.617592e+14, dt/cycle=0.027s
# ML/o/p     #5307 LLK=     2.73(p)     1.52(g)     1.52(e), nb photons=1.617592e+14, dt/cycle=0.028s
# ML/o/p     #5312 LLK=     2.73(p)     1.52(g)     1.52(e), nb photons=1.617592e+14, dt/cycle=0.027s
# ML/o/p     #5317 LLK=     2.73(p)     1.52(g)     1.52(e), nb photons=1.617593e+14, dt/cycle=0.027s
# ML/o/p     #5322 LLK=     2.72(p)     1.52(g)     1.52(e), nb photons=1.617593e+14, dt/cycle=0.028s
# ML/o/p     #5327 LLK=     2.73(p)     1.51(g)     1.51(e), nb photons=1.617592e+14, dt/cycle=0.027s
# ML/o/p     #5332 LLK=     2.72(p)     1.51(g)     1.51(e), nb photons=1.617593e+14, dt/cycle=0.027s
# ML/o/p     #5337 LLK=     2.72(p)     1.51(g)     1.51(e), nb photons=1.617593e+14, dt/cycle=0.027s
# ML/o/p     #5342 LLK=     2.72(p)     1.50(g)     1.50(e), nb photons=1.617593e+14, dt/cycle=0.027s
# ML/o/p     #5347 LLK=     2.72(p)     1.50(g)     1.50(e), nb photons=1.617592e+14, dt/cycle=0.027s
# ML/o/p     #5352 LLK=     2.72(p)     1.50(g)     1.50(e), nb photons=1.617592e+14, dt/cycle=0.028s
# ML/o/p     #5357 LLK=     2.72(p)     1.50(g)     1.50(e), nb photons=1.617593e+14, dt/cycle=0.028s
# ML/o/p     #5362 LLK=     2.72(p)     1.49(g)     1.49(e), nb photons=1.617592e+14, dt/cycle=0.028s
# ML/o/p     #5367 LLK=     2.72(p)     1.49(g)     1.49(e), nb photons=1.617592e+14, dt/cycle=0.027s
# ML/o/p     #5372 LLK=     2.71(p)     1.49(g)     1.49(e), nb photons=1.617592e+14, dt/cycle=0.028s
# ML/o/p     #5377 LLK=     2.71(p)     1.49(g)     1.49(e), nb photons=1.617593e+14, dt/cycle=0.028s
# ML/o/p     #5382 LLK=     2.71(p)     1.48(g)     1.48(e), nb photons=1.617592e+14, dt/cycle=0.027s
# ML/o/p     #5387 LLK=     2.71(p)     1.48(g)     1.48(e), nb photons=1.617592e+14, dt/cycle=0.027s
# ML/o/p     #5392 LLK=     2.71(p)     1.48(g)     1.48(e), nb photons=1.617592e+14, dt/cycle=0.027s
# ML/o/p     #5397 LLK=     2.71(p)     1.47(g)     1.47(e), nb photons=1.617593e+14, dt/cycle=0.028s
# ML/o/p     #5402 LLK=     2.70(p)     1.47(g)     1.47(e), nb photons=1.617592e+14, dt/cycle=0.028s
# ML/o/p     #5407 LLK=     2.70(p)     1.47(g)     1.47(e), nb photons=1.617592e+14, dt/cycle=0.027s
# ML/o/p     #5412 LLK=     2.70(p)     1.47(g)     1.47(e), nb photons=1.617593e+14, dt/cycle=0.028s
# ML/o/p     #5417 LLK=     2.70(p)     1.47(g)     1.47(e), nb photons=1.617593e+14, dt/cycle=0.029s
# ML/o/p     #5422 LLK=     2.70(p)     1.46(g)     1.46(e), nb photons=1.617593e+14, dt/cycle=0.028s
# ML/o/p     #5427 LLK=     2.70(p)     1.46(g)     1.46(e), nb photons=1.617592e+14, dt/cycle=0.028s
# ML/o/p     #5432 LLK=     2.70(p)     1.46(g)     1.46(e), nb photons=1.617593e+14, dt/cycle=0.028s
# ML/o/p     #5437 LLK=     2.69(p)     1.46(g)     1.46(e), nb photons=1.617593e+14, dt/cycle=0.028s
# ML/o/p     #5442 LLK=     2.70(p)     1.45(g)     1.45(e), nb photons=1.617592e+14, dt/cycle=0.027s
# ML/o/p     #5447 LLK=     2.70(p)     1.45(g)     1.45(e), nb photons=1.617592e+14, dt/cycle=0.027s
# ML/o/p     #5452 LLK=     2.70(p)     1.45(g)     1.45(e), nb photons=1.617592e+14, dt/cycle=0.028s
# ML/o/p     #5457 LLK=     2.69(p)     1.45(g)     1.45(e), nb photons=1.617593e+14, dt/cycle=0.027s
# ML/o/p     #5462 LLK=     2.69(p)     1.45(g)     1.45(e), nb photons=1.617592e+14, dt/cycle=0.028s
# ML/o/p     #5467 LLK=     2.69(p)     1.44(g)     1.44(e), nb photons=1.617592e+14, dt/cycle=0.028s
# ML/o/p     #5472 LLK=     2.69(p)     1.44(g)     1.44(e), nb photons=1.617592e+14, dt/cycle=0.028s
# ML/o/p     #5477 LLK=     2.69(p)     1.44(g)     1.44(e), nb photons=1.617593e+14, dt/cycle=0.027s
# ML/o/p     #5482 LLK=     2.69(p)     1.44(g)     1.44(e), nb photons=1.617592e+14, dt/cycle=0.027s
# ML/o/p     #5487 LLK=     2.69(p)     1.44(g)     1.44(e), nb photons=1.617592e+14, dt/cycle=0.027s
# ML/o/p     #5492 LLK=     2.69(p)     1.44(g)     1.44(e), nb photons=1.617592e+14, dt/cycle=0.028s
# ML/o/p     #5497 LLK=     2.69(p)     1.43(g)     1.43(e), nb photons=1.617593e+14, dt/cycle=0.027s
# ML/o/p     #5502 LLK=     2.68(p)     1.43(g)     1.43(e), nb photons=1.617593e+14, dt/cycle=0.027s
# ML/o/p     #5507 LLK=     2.69(p)     1.43(g)     1.43(e), nb photons=1.617592e+14, dt/cycle=0.027s
# ML/o/p     #5512 LLK=     2.68(p)     1.43(g)     1.43(e), nb photons=1.617592e+14, dt/cycle=0.027s
# ML/o/p     #5517 LLK=     2.68(p)     1.43(g)     1.43(e), nb photons=1.617592e+14, dt/cycle=0.028s
# ML/o/p     #5522 LLK=     2.68(p)     1.42(g)     1.42(e), nb photons=1.617593e+14, dt/cycle=0.027s
# ML/o/p     #5527 LLK=     2.68(p)     1.42(g)     1.42(e), nb photons=1.617592e+14, dt/cycle=0.027s
# ML/o/p     #5532 LLK=     2.68(p)     1.42(g)     1.42(e), nb photons=1.617592e+14, dt/cycle=0.028s
# ML/o/p     #5537 LLK=     2.68(p)     1.42(g)     1.42(e), nb photons=1.617592e+14, dt/cycle=0.027s
# ML/o/p     #5542 LLK=     2.68(p)     1.42(g)     1.42(e), nb photons=1.617593e+14, dt/cycle=0.027s
# ML/o/p     #5547 LLK=     2.68(p)     1.41(g)     1.41(e), nb photons=1.617592e+14, dt/cycle=0.027s
# ML/o/p     #5552 LLK=     2.68(p)     1.41(g)     1.41(e), nb photons=1.617592e+14, dt/cycle=0.027s
# ML/o/p     #5557 LLK=     2.68(p)     1.41(g)     1.41(e), nb photons=1.617592e+14, dt/cycle=0.028s
# ML/o/p     #5562 LLK=     2.67(p)     1.41(g)     1.41(e), nb photons=1.617592e+14, dt/cycle=0.027s
# ML/o/p     #5567 LLK=     2.67(p)     1.41(g)     1.41(e), nb photons=1.617593e+14, dt/cycle=0.029s
# ML/o/p     #5572 LLK=     2.67(p)     1.40(g)     1.40(e), nb photons=1.617592e+14, dt/cycle=0.027s
# ML/o/p     #5577 LLK=     2.67(p)     1.40(g)     1.40(e), nb photons=1.617592e+14, dt/cycle=0.027s
# ML/o/p     #5582 LLK=     2.67(p)     1.40(g)     1.40(e), nb photons=1.617593e+14, dt/cycle=0.027s
# ML/o/p     #5587 LLK=     2.67(p)     1.40(g)     1.40(e), nb photons=1.617593e+14, dt/cycle=0.028s
# ML/o/p     #5592 LLK=     2.66(p)     1.40(g)     1.40(e), nb photons=1.617592e+14, dt/cycle=0.027s
# ML/o/p     #5597 LLK=     2.67(p)     1.39(g)     1.39(e), nb photons=1.617592e+14, dt/cycle=0.028s
# ML/o/p     #5602 LLK=     2.67(p)     1.39(g)     1.39(e), nb photons=1.617592e+14, dt/cycle=0.027s
# ML/o/p     #5607 LLK=     2.66(p)     1.39(g)     1.39(e), nb photons=1.617593e+14, dt/cycle=0.028s
# ML/o/p     #5612 LLK=     2.66(p)     1.39(g)     1.39(e), nb photons=1.617593e+14, dt/cycle=0.028s
# ML/o/p     #5617 LLK=     2.66(p)     1.39(g)     1.39(e), nb photons=1.617592e+14, dt/cycle=0.028s
# ML/o/p     #5622 LLK=     2.67(p)     1.38(g)     1.38(e), nb photons=1.617592e+14, dt/cycle=0.028s
# ML/o/p     #5627 LLK=     2.66(p)     1.38(g)     1.38(e), nb photons=1.617592e+14, dt/cycle=0.028s
# ML/o/p     #5632 LLK=     2.66(p)     1.38(g)     1.38(e), nb photons=1.617592e+14, dt/cycle=0.028s
# ML/o/p     #5637 LLK=     2.66(p)     1.38(g)     1.38(e), nb photons=1.617592e+14, dt/cycle=0.028s
# ML/o/p     #5642 LLK=     2.66(p)     1.38(g)     1.38(e), nb photons=1.617592e+14, dt/cycle=0.027s
# ML/o/p     #5647 LLK=     2.66(p)     1.37(g)     1.37(e), nb photons=1.617592e+14, dt/cycle=0.027s
# ML/o/p     #5652 LLK=     2.66(p)     1.37(g)     1.37(e), nb photons=1.617592e+14, dt/cycle=0.027s
# ML/o/p     #5657 LLK=     2.65(p)     1.37(g)     1.37(e), nb photons=1.617593e+14, dt/cycle=0.028s
# ML/o/p     #5662 LLK=     2.65(p)     1.37(g)     1.37(e), nb photons=1.617592e+14, dt/cycle=0.028s
# ML/o/p     #5667 LLK=     2.66(p)     1.37(g)     1.37(e), nb photons=1.617592e+14, dt/cycle=0.027s
# ML/o/p     #5672 LLK=     2.65(p)     1.37(g)     1.37(e), nb photons=1.617592e+14, dt/cycle=0.028s
# ML/o/p     #5677 LLK=     2.65(p)     1.36(g)     1.36(e), nb photons=1.617593e+14, dt/cycle=0.028s
# ML/o/p     #5682 LLK=     2.65(p)     1.36(g)     1.36(e), nb photons=1.617593e+14, dt/cycle=0.028s
# ML/o/p     #5687 LLK=     2.65(p)     1.36(g)     1.36(e), nb photons=1.617592e+14, dt/cycle=0.027s
# ML/o/p     #5692 LLK=     2.65(p)     1.36(g)     1.36(e), nb photons=1.617592e+14, dt/cycle=0.027s
# ML/o/p     #5697 LLK=     2.65(p)     1.36(g)     1.36(e), nb photons=1.617592e+14, dt/cycle=0.027s
# ML/o/p     #5702 LLK=     2.65(p)     1.36(g)     1.36(e), nb photons=1.617593e+14, dt/cycle=0.027s
# ML/o/p     #5707 LLK=     2.65(p)     1.36(g)     1.36(e), nb photons=1.617593e+14, dt/cycle=0.028s
# ML/o/p     #5712 LLK=     2.65(p)     1.35(g)     1.35(e), nb photons=1.617592e+14, dt/cycle=0.028s
# ML/o/p     #5717 LLK=     2.64(p)     1.35(g)     1.35(e), nb photons=1.617592e+14, dt/cycle=0.027s
# ML/o/p     #5722 LLK=     2.65(p)     1.35(g)     1.35(e), nb photons=1.617593e+14, dt/cycle=0.028s
# ML/o/p     #5727 LLK=     2.64(p)     1.35(g)     1.35(e), nb photons=1.617592e+14, dt/cycle=0.027s
# ML/o/p     #5732 LLK=     2.65(p)     1.35(g)     1.35(e), nb photons=1.617592e+14, dt/cycle=0.027s
# ML/o/p     #5737 LLK=     2.64(p)     1.35(g)     1.35(e), nb photons=1.617592e+14, dt/cycle=0.027s
# ML/o/p     #5742 LLK=     2.64(p)     1.35(g)     1.35(e), nb photons=1.617592e+14, dt/cycle=0.027s
# ML/o/p     #5747 LLK=     2.64(p)     1.35(g)     1.35(e), nb photons=1.617592e+14, dt/cycle=0.028s
# ML/o/p     #5752 LLK=     2.64(p)     1.34(g)     1.34(e), nb photons=1.617592e+14, dt/cycle=0.028s
# ML/o/p     #5757 LLK=     2.64(p)     1.34(g)     1.34(e), nb photons=1.617592e+14, dt/cycle=0.028s
# ML/o/p     #5762 LLK=     2.64(p)     1.34(g)     1.34(e), nb photons=1.617593e+14, dt/cycle=0.027s
# ML/o/p     #5767 LLK=     2.64(p)     1.34(g)     1.34(e), nb photons=1.617592e+14, dt/cycle=0.027s
# ML/o/p     #5772 LLK=     2.64(p)     1.34(g)     1.34(e), nb photons=1.617592e+14, dt/cycle=0.028s
# ML/o/p     #5777 LLK=     2.64(p)     1.34(g)     1.34(e), nb photons=1.617593e+14, dt/cycle=0.028s
# ML/o/p     #5782 LLK=     2.64(p)     1.33(g)     1.33(e), nb photons=1.617593e+14, dt/cycle=0.028s
# ML/o/p     #5787 LLK=     2.64(p)     1.33(g)     1.33(e), nb photons=1.617592e+14, dt/cycle=0.027s
# ML/o/p     #5792 LLK=     2.63(p)     1.33(g)     1.33(e), nb photons=1.617592e+14, dt/cycle=0.027s
# ML/o/p     #5797 LLK=     2.63(p)     1.33(g)     1.33(e), nb photons=1.617593e+14, dt/cycle=0.027s
# ML/o/p     #5802 LLK=     2.63(p)     1.33(g)     1.33(e), nb photons=1.617593e+14, dt/cycle=0.028s
# ML/o/p     #5807 LLK=     2.64(p)     1.32(g)     1.32(e), nb photons=1.617592e+14, dt/cycle=0.028s
# ML/o/p     #5812 LLK=     2.63(p)     1.32(g)     1.32(e), nb photons=1.617592e+14, dt/cycle=0.028s
# ML/o/p     #5817 LLK=     2.63(p)     1.32(g)     1.32(e), nb photons=1.617593e+14, dt/cycle=0.027s
# ML/o/p     #5822 LLK=     2.63(p)     1.32(g)     1.32(e), nb photons=1.617592e+14, dt/cycle=0.028s
# ML/o/p     #5827 LLK=     2.63(p)     1.32(g)     1.32(e), nb photons=1.617592e+14, dt/cycle=0.028s
# ML/o/p     #5832 LLK=     2.63(p)     1.32(g)     1.32(e), nb photons=1.617592e+14, dt/cycle=0.027s
# ML/o/p     #5837 LLK=     2.63(p)     1.32(g)     1.32(e), nb photons=1.617593e+14, dt/cycle=0.027s
# ML/o/p     #5842 LLK=     2.63(p)     1.31(g)     1.31(e), nb photons=1.617592e+14, dt/cycle=0.028s
# ML/o/p     #5847 LLK=     2.63(p)     1.31(g)     1.31(e), nb photons=1.617592e+14, dt/cycle=0.027s
# ML/o/p     #5852 LLK=     2.62(p)     1.31(g)     1.31(e), nb photons=1.617592e+14, dt/cycle=0.027s
# ML/o/p     #5857 LLK=     2.63(p)     1.31(g)     1.31(e), nb photons=1.617592e+14, dt/cycle=0.027s
# ML/o/p     #5862 LLK=     2.63(p)     1.31(g)     1.31(e), nb photons=1.617593e+14, dt/cycle=0.027s
# ML/o/p     #5867 LLK=     2.62(p)     1.31(g)     1.31(e), nb photons=1.617592e+14, dt/cycle=0.029s
# ML/o/p     #5872 LLK=     2.62(p)     1.31(g)     1.31(e), nb photons=1.617592e+14, dt/cycle=0.027s
# ML/o/p     #5877 LLK=     2.62(p)     1.31(g)     1.31(e), nb photons=1.617592e+14, dt/cycle=0.028s
# ML/o/p     #5882 LLK=     2.62(p)     1.30(g)     1.30(e), nb photons=1.617593e+14, dt/cycle=0.028s
# ML/o/p     #5887 LLK=     2.62(p)     1.30(g)     1.30(e), nb photons=1.617592e+14, dt/cycle=0.027s
# ML/o/p     #5892 LLK=     2.62(p)     1.30(g)     1.30(e), nb photons=1.617592e+14, dt/cycle=0.027s
# ML/o/p     #5897 LLK=     2.62(p)     1.30(g)     1.30(e), nb photons=1.617592e+14, dt/cycle=0.027s
# ML/o/p     #5902 LLK=     2.62(p)     1.30(g)     1.30(e), nb photons=1.617593e+14, dt/cycle=0.028s
# ML/o/p     #5907 LLK=     2.62(p)     1.30(g)     1.30(e), nb photons=1.617593e+14, dt/cycle=0.027s
# ML/o/p     #5912 LLK=     2.62(p)     1.30(g)     1.30(e), nb photons=1.617592e+14, dt/cycle=0.028s
# ML/o/p     #5917 LLK=     2.62(p)     1.30(g)     1.30(e), nb photons=1.617592e+14, dt/cycle=0.028s
# ML/o/p     #5922 LLK=     2.62(p)     1.30(g)     1.30(e), nb photons=1.617592e+14, dt/cycle=0.028s
# ML/o/p     #5927 LLK=     2.62(p)     1.29(g)     1.29(e), nb photons=1.617593e+14, dt/cycle=0.027s
# ML/o/p     #5932 LLK=     2.62(p)     1.29(g)     1.29(e), nb photons=1.617592e+14, dt/cycle=0.027s
# ML/o/p     #5937 LLK=     2.62(p)     1.29(g)     1.29(e), nb photons=1.617592e+14, dt/cycle=0.027s
# ML/o/p     #5942 LLK=     2.61(p)     1.29(g)     1.29(e), nb photons=1.617592e+14, dt/cycle=0.028s
# ML/o/p     #5947 LLK=     2.62(p)     1.29(g)     1.29(e), nb photons=1.617592e+14, dt/cycle=0.028s
# ML/o/p     #5952 LLK=     2.61(p)     1.29(g)     1.29(e), nb photons=1.617593e+14, dt/cycle=0.027s
# ML/o/p     #5957 LLK=     2.61(p)     1.29(g)     1.29(e), nb photons=1.617592e+14, dt/cycle=0.028s
# ML/o/p     #5962 LLK=     2.62(p)     1.29(g)     1.29(e), nb photons=1.617592e+14, dt/cycle=0.028s
# ML/o/p     #5967 LLK=     2.61(p)     1.29(g)     1.29(e), nb photons=1.617592e+14, dt/cycle=0.028s
# ML/o/p     #5972 LLK=     2.61(p)     1.28(g)     1.28(e), nb photons=1.617593e+14, dt/cycle=0.028s
# ML/o/p     #5977 LLK=     2.61(p)     1.28(g)     1.28(e), nb photons=1.617593e+14, dt/cycle=0.027s
# ML/o/p     #5982 LLK=     2.61(p)     1.28(g)     1.28(e), nb photons=1.617593e+14, dt/cycle=0.028s
# ML/o/p     #5987 LLK=     2.61(p)     1.28(g)     1.28(e), nb photons=1.617592e+14, dt/cycle=0.028s
# ML/o/p     #5992 LLK=     2.61(p)     1.28(g)     1.28(e), nb photons=1.617592e+14, dt/cycle=0.027s
# ML/o/p     #5997 LLK=     2.61(p)     1.28(g)     1.28(e), nb photons=1.617593e+14, dt/cycle=0.027s
# ML/o/p     #6001 LLK=     2.61(p)     1.28(g)     1.28(e), nb photons=1.617592e+14, dt/cycle=0.028s
# Maximum likelihood optimization completed!
